# %%
import pandas as pd
import datetime as dt
import sys
sys.path.append('../')
import pipeline as p

# %% [markdown]
# ### Print out model cols so we can copy to 'forecast.py'

# %%
model_cols = p.open_pkl('data/model_cols.pkl')

# %%
model_cols
# Out:
# ['PenY_SA1',
#  'elo1',
#  'PtsOpp_SA1',
#  'RushAtt_SA1',
#  'PtsTm_SA2',
#  'elo2',
#  'Penalies_SA2',
#  'TimePossMins1',
#  'FirstD_SA2',
#  'playoff',
#  'PtsOpp_SA2',
#  'WinPct1',
#  'TimePossMins2',
#  'FourthDAtt_SA1',
#  'WinPct2']

# %% [markdown]
# ### Archive files

# %%
# !mv data/nfl_games.csv data/nfl_games_old.csv

# %% [markdown]
# ### Reset inital elos:

# %%
init_elos = pd.read_csv('data/initial_elos.csv')

# %%
init_elos.head()
# Out:
#   team       elo
# 0  RII  1503.947
# 1  STP  1300.000
# 2  BFF  1478.004
# 3  WBU  1300.000
# 4  RCH  1503.420

# %%
# this df contains week 1 data
df2 = p.open_pkl('data/model_df2.pkl')

# %%
df2.head(17)
# Out:
#          date  season  neutral  playoff team1 team2      elo1      elo2  \
# 0  2007-09-06    2007        0        0   IND    NO  1653.923  1515.973
# 1  2007-09-09    2007        0        0   WSH   MIA  1448.841  1489.941
# 2  2007-09-09    2007        0        0   BUF   DEN  1516.684  1558.574
# 3  2007-09-09    2007        0        0   SEA    TB  1511.936  1417.385
# 4  2007-09-09    2007        0        0   CLE   PIT  1396.563  1568.569
# 5  2007-09-09    2007        0        0    GB   PHI  1497.051  1542.727
# 6  2007-09-09    2007        0        0   HOU    KC  1433.947  1539.589
# 7  2007-09-09    2007        0        0   JAX   TEN  1544.671  1494.678
# 8  2007-09-09    2007        0        0   MIN   ATL  1436.774  1448.286
# 9  2007-09-09    2007        0        0   NYJ    NE  1514.095  1633.017
# 10 2007-09-09    2007        0        0   LAR   CAR  1478.632  1511.942
# 11 2007-09-09    2007        0        0   LAC   CHI  1646.204  1574.744
# 12 2007-09-09    2007        0        0   OAK   DET  1350.910  1388.019
# 13 2007-09-09    2007        0        0   DAL   NYG  1490.892  1494.060
# 14 2007-09-10    2007        0        0   CIN   BAL  1539.318  1605.477
# 15 2007-09-10    2007        0        0    SF   ARI  1439.211  1439.210
# 16 2007-09-16    2007        0        0   DET   MIN  1418.350  1462.342
#
#     elo_prob1  score1       ...        INT_SA2  SacksO_SA2  Fumbles_SA2  \
# 0    0.762833      41       ...            NaN         NaN          NaN
# 1    0.534341      16       ...            NaN         NaN          NaN
# 2    0.533209      14       ...            NaN         NaN          NaN
# 3    0.714726      20       ...            NaN         NaN          NaN
# 4    0.350697       7       ...            NaN         NaN          NaN
# 5    0.527781      16       ...            NaN         NaN          NaN
# 6    0.441777      20       ...            NaN         NaN          NaN
# 7    0.659699      10       ...            NaN         NaN          NaN
# 8    0.576373      24       ...            NaN         NaN          NaN
# 9    0.423017      14       ...            NaN         NaN          NaN
# 10   0.545480      13       ...            NaN         NaN          NaN
# 11   0.686870      14       ...            NaN         NaN          NaN
# 12   0.540052      21       ...            NaN         NaN          NaN
# 13   0.588056      45       ...            NaN         NaN          NaN
# 14   0.498332      27       ...            NaN         NaN          NaN
# 15   0.592468      20       ...            NaN         NaN          NaN
# 16   0.530196      20       ...            1.0         0.0          1.0
#
#     Penalies_SA2 PenY_SA2  ThirdDConv_SA2  ThirdDAtt_SA2  FourthDAtt_SA2  \
# 0            NaN      NaN             NaN            NaN             NaN
# 1            NaN      NaN             NaN            NaN             NaN
# 2            NaN      NaN             NaN            NaN             NaN
# 3            NaN      NaN             NaN            NaN             NaN
# 4            NaN      NaN             NaN            NaN             NaN
# 5            NaN      NaN             NaN            NaN             NaN
# 6            NaN      NaN             NaN            NaN             NaN
# 7            NaN      NaN             NaN            NaN             NaN
# 8            NaN      NaN             NaN            NaN             NaN
# 9            NaN      NaN             NaN            NaN             NaN
# 10           NaN      NaN             NaN            NaN             NaN
# 11           NaN      NaN             NaN            NaN             NaN
# 12           NaN      NaN             NaN            NaN             NaN
# 13           NaN      NaN             NaN            NaN             NaN
# 14           NaN      NaN             NaN            NaN             NaN
# 15           NaN      NaN             NaN            NaN             NaN
# 16           4.0     35.0             3.0            9.0             0.0
#
#     PassCompPct_SA2  PassRating_SA2
# 0               NaN             NaN
# 1               NaN             NaN
# 2               NaN             NaN
# 3               NaN             NaN
# 4               NaN             NaN
# 5               NaN             NaN
# 6               NaN             NaN
# 7               NaN             NaN
# 8               NaN             NaN
# 9               NaN             NaN
# 10              NaN             NaN
# 11              NaN             NaN
# 12              NaN             NaN
# 13              NaN             NaN
# 14              NaN             NaN
# 15              NaN             NaN
# 16        56.521739        75.09058
#
# [17 rows x 66 columns]

# %% [markdown]
# For purposes of comparing my model to FiveThirtyEight's predictions, I need to define 'inital elo' ratings as team's Elo's going into the 1st week of 2007.

# %%
init_elo_dict = {}

# The first week comprises 16 games (or, the first 16 rows in df2)
for i in range(17):
    tm1 = df2.loc[i,'team1']
    tm2 = df2.loc[i,'team2']
    init_elo_dict[tm1] = df2.loc[i,'elo1']
    init_elo_dict[tm2] = df2.loc[i,'elo2']

# %%
len(init_elo_dict)
# Out:
# 32

# %%
init_df2 = pd.DataFrame.from_dict(init_elo_dict, orient='index')
init_df2.reset_index(inplace=True)
init_df2.columns=['team','elo']

# %%
init_df2
# Out:
#    team       elo
# 0   MIA  1489.941
# 1    NO  1515.973
# 2   LAC  1646.204
# 3    NE  1633.017
# 4   WSH  1448.841
# 5   BUF  1516.684
# 6   DAL  1490.892
# 7   BAL  1605.477
# 8   IND  1653.923
# 9   CLE  1396.563
# 10   KC  1539.589
# 11  PIT  1568.569
# 12  HOU  1433.947
# 13   SF  1439.211
# 14   GB  1497.051
# 15  NYJ  1514.095
# 16  ATL  1448.286
# 17  MIN  1462.342
# 18  NYG  1494.060
# 19  CIN  1539.318
# 20  PHI  1542.727
# 21  OAK  1350.910
# 22  TEN  1494.678
# 23  CAR  1511.942
# 24  DEN  1558.574
# 25  JAX  1544.671
# 26  CHI  1574.744
# 27  DET  1418.350
# 28  SEA  1511.936
# 29   TB  1417.385
# 30  LAR  1478.632
# 31  ARI  1439.210

# %%
# !ls
# Out:
# LICENSE         README.md       data            forecast.py     util.py
# MyPred-01.ipynb __pycache__     eval.py         pipeline.py

# %%
# !mv data/initial_elos.csv data/initial_elos_old.csv

# %%
init_df2.to_csv('data/initial_elos.csv')

# %%
df2.to_csv('data/nfl_games.csv',index=False)

# %% [markdown]
# Test FiveThirtyEight's code for reading in "games" from 'nfl_games.csv'

# %%
import csv

# %%
def read_games(file):
    """ Initializes game objects from csv """
    games = [item for item in csv.DictReader(open(file))]

    # Uncommenting these three lines will grab the latest game results for 2018, update team ratings accordingly, and make forecasts for upcoming games
    #file_2018 = file.replace(".", "_2018.")
    #urlretrieve("https://projects.fivethirtyeight.com/nfl-api/2018/nfl_games_2018.csv", file_2018)
    #games += [item for item in csv.DictReader(open(file_2018))]

    for game in games:
        game['season'], game['neutral'], game['playoff'] = int(game['season']), int(game['neutral']), int(game['playoff'])
        game['score1'], game['score2'] = int(game['score1']) if game['score1'] != '' else None, int(game['score2']) if game['score2'] != '' else None
        game['elo_prob1'], game['result1'] = float(game['elo_prob1']) if game['elo_prob1'] != '' else None, float(game['result1']) if game['result1'] != '' else None

    return games

# %%
games = read_games('data/nfl_games.csv')

# %%
game = games[0]

# %%
for col in model_cols:
    game[col] = float(game[col]) if game[col] != '' else None

# %%
game
# Out:
# {'DefTO_SA1': '',
#  'DefTO_SA2': '',
#  'FirstD_SA1': '',
#  'FirstD_SA2': None,
#  'FourthDAtt_SA1': None,
#  'FourthDAtt_SA2': '',
#  'Fumbles_SA1': '',
#  'Fumbles_SA2': '',
#  'INT_SA1': '',
#  'INT_SA2': '',
#  'OT': '0',
#  'PassAtt_SA1': '',
#  'PassAtt_SA2': '',
#  'PassCmp_SA1': '',
#  'PassCmp_SA2': '',
#  'PassCompPct_SA1': '',
#  'PassCompPct_SA2': '',
#  'PassRating_SA1': '',
#  'PassRating_SA2': '',
#  'PassTDs_SA1': '',
#  'PassTDs_SA2': '',
#  'PassY_SA1': '',
#  'PassY_SA2': '',
#  'PenY_SA1': None,
#  'PenY_SA2': '',
#  'Penalies_SA1': '',
#  'Penalies_SA2': None,
#  'PtsOpp_SA1': None,
#  'PtsOpp_SA2': None,
#  'PtsTm_SA1': '',
#  'PtsTm_SA2': None,
#  'RushAtt_SA1': None,
#  'RushAtt_SA2': '',
#  'RushTDs_SA1': '',
#  'RushTDs_SA2': '',
#  'RushY_SA1': '',
#  'RushY_SA2': '',
#  'SacksO_SA1': '',
#  'SacksO_SA2': '',
#  'TO_SA1': '',
#  'TO_SA2': '',
#  'ThirdDAtt_SA1': '',
#  'ThirdDAtt_SA2': '',
#  'ThirdDConv_SA1': '',
#  'ThirdDConv_SA2': '',
#  'TimePossMins1': 28.25,
#  'TimePossMins2': 31.75,
#  'TotY_SA1': '',
#  'TotY_SA2': '',
#  'WinPct1': 100.0,
#  'WinPct2': 0.0,
#  'date': '2007-09-06',
#  'elo1': 1653.9229999999998,
#  'elo2': 1515.973,
#  'elo_delta1': '15.051000000000158',
#  'elo_prob1': 0.7628329116106539,
#  'neutral': 0,
#  'playoff': 0.0,
#  'result1': 1.0,
#  'score1': 41,
#  'score2': 10,
#  'season': 2007,
#  'team1': 'IND',
#  'team2': 'NO',
#  'time': '20:39:00',
#  'week': '1'}

# %%
gdf = pd.DataFrame.from_dict(game, orient='index').transpose()

# %%
gdf[model_cols]
# Out:
#   PenY_SA1     elo1 PtsOpp_SA1 RushAtt_SA1 PtsTm_SA2     elo2 Penalies_SA2  \
# 0     None  1653.92       None        None      None  1515.97         None
#
#   TimePossMins1 FirstD_SA2 playoff PtsOpp_SA2 WinPct1 TimePossMins2  \
# 0         28.25       None       0       None     100         31.75
#
#   FourthDAtt_SA1 WinPct2
# 0           None       0

# %%
gdf[['week']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-8c0da486fb38> in <module>()
# ----> 1 gdf[['week']]
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['week'] not in index"

# %%
dum = gdf[model_cols]

# %%
for x in dum:
    try:
        print(float(x))
    except ValueError:
        print(None)
# Out:
# nan
# 1448.1190807611802
# 28.0
# nan
# 12.0
# 1638.13804913745
# 8.0
# nan
# 21.0
# 0.0
# 10.0
# 50.0
# 30.05
# nan
# 50.0
